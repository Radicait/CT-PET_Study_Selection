# %%
# reading study list report:
import pandas as pd

report_csv_path = "/home/sina/gradient-data/Radiology_reports_extraction_pipeline/gradient_pt_ct_all_pairs_query.csv"
df = pd.read_csv(report_csv_path)
print(f"Loaded report: {df.shape[0]} rows, {df.shape[1]} columns")
df.head()
# Out:
# Loaded report: 4564 rows, 14 columns
#                                            pt_row_id  \
# 0  339587749236740102455301864528816464077.284193...
# 1  56893976444676694709814413572352018399.3053508...
# 2  115961738801034610733969772565477341670.203749...
# 3  169273916834626603348007141775616224451.879896...
# 4  39319603764106001291963207120622313706.1371145...
#
#                                         pt_study_uid        patient_id  \
# 0  1.2.826.0.1.3680043.8.498.35754402622244938816...  GRDNTZ99QT8Y5NMZ
# 1  1.2.826.0.1.3680043.8.498.87392152933652660721...  GRDNBTG33DBDYZHJ
# 2  1.2.826.0.1.3680043.8.498.35763792184605873872...  GRDNJCNULBJJUATX
# 3  1.2.826.0.1.3680043.8.498.97769620527488986931...  GRDNSDFEXJ9QPL92
# 4  1.2.826.0.1.3680043.8.498.12029078855088565547...  GRDN1K30BA2XZ945
#
#   pt_modality pt_acquisition_date  \
# 0          PT          2010-04-18
# 1          PT          2020-01-05
# 2          PT          2022-08-29
# 3          PT          2022-02-21
# ...

# %%
# reading study list report:
import pandas as pd

report_csv_path = "/home/sina/gradient-data/reports_data/df_unique.csv"
df = pd.read_csv(report_csv_path)
print(f"Loaded report: {df.shape[0]} rows, {df.shape[1]} columns")
df.head()
# Out:
# Loaded report: 12481 rows, 24 columns
#                                               row_id             institution  \
# 0  '279259046719878799006833465447967742425.31940...  thryothor-495511-PU2Q5
# 1  '310440780324215030840303534268304848871.24598...  thryothor-495511-IQYWW
# 2  '147571275528231300255694101948702718658.13836...  thryothor-495511-other
# 3  '2166798648691988519519301241311180052.9051850...      quelea-19938-SIIBL
# 4  '140040631785331202643719215388457666810.11935...      quelea-19938-SIIBL
#
#          patient_id  accession_number  \
# 0  GRDNUZRVW4JEM8P9  GRDNS51T16OKQPCI
# 1  GRDNJD8SBOFBR1KP  GRDNNTYL1L7K9GR2
# 2  GRDNTBDBE6UMTAAC  GRDNYKC5OY4XNUON
# 3  GRDNHKS94TXSZDUP  GRDNAZDUUA4JDDUY
# 4  GRDN2CACCKITTET0  GRDNTANKZNF1VSWO
#
#                                  deid_english_report study_date  \
# 0  CLINICAL DATA:  Initial treatment strategy for...    8/30/16
# 1  CLINICAL DATA:  Initial treatment strategy for...    4/22/19
# ...
